# %% [markdown]
# ### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import pandas as pd
from pathlib import Path

# File to Load (Remember to Change These)
school_data_to_load = Path("Resources/schools_complete.csv")
student_data_to_load = Path("Resources/students_complete.csv")

# Read School and Student Data File and store into Pandas DataFrames
school_data = pd.read_csv(school_data_to_load)
student_data = pd.read_csv(student_data_to_load)

# Combine the data into a single dataset.  
school_data_complete = pd.merge(student_data, school_data, how="left", on=["school_name", "school_name"])

# %% [markdown]
# ## Local Government Area Summary
#
# * Calculate the total number of schools
#
# * Calculate the total number of students
#
# * Calculate the total budget
#
# * Calculate the average maths score
#
# * Calculate the average reading score
#
# * Calculate the percentage of students with a passing maths score (50 or greater)
#
# * Calculate the percentage of students with a passing reading score (50 or greater)
#
# * Calculate the percentage of students who passed maths **and** reading (% Overall Passing)
#
# * Create a dataframe to hold the above results
#
# * Optional: give the displayed data cleaner formatting

# %%
# Calculate the total number of unique schools
total_unique_schools = school_data_complete['school_name'].nunique()

# Create a DataFrame with the key metric
local_government_area_summary = pd.DataFrame({"Total Unique Schools": [total_unique_schools]})

# Calculate the total number of students
total_students = school_data_complete['Student ID'].count()

# Add the result to the existing DataFrame
local_government_area_summary["Total Students"] = total_students

# Calculate the total budget
total_budget = school_data['budget'].sum()

# Add the result to the existing DataFrame
local_government_area_summary["Total Budget"] = total_budget

# Calculate the average math score
average_math_score = school_data_complete['maths_score'].mean()

# Add the result to the existing DataFrame
local_government_area_summary["Average Maths Score"] = average_math_score

# Calculate the average reading score
average_reading_score = school_data_complete['reading_score'].mean()

# Add the result to the existing DataFrame
local_government_area_summary["Average Reading Score"] = average_reading_score

# Calculate the percentage passing math
passing_math_percentage = (school_data_complete['maths_score'] >= 50).mean() * 100

# Add the result to the existing DataFrame
local_government_area_summary["% Passing Math"] = passing_math_percentage

# Calculate the percentage passing reading
passing_reading_percentage = (school_data_complete['reading_score'] >= 50).mean() * 100

# Add the result to the existing DataFrame
local_government_area_summary["% Passing Reading"] = passing_reading_percentage

# Calculate the percentage passing overall (both math and reading)
passing_overall_percentage = ((school_data_complete['maths_score'] >= 50) & (school_data_complete['reading_score'] >= 50)).mean() * 100

# Add the result to the existing DataFrame
local_government_area_summary["% Overall Passing"] = passing_overall_percentage

# Format the Total Students and Total Budget columns
local_government_area_summary["Total Students"] = local_government_area_summary["Total Students"].map("{:,}".format)
local_government_area_summary["Total Budget"] = local_government_area_summary["Total Budget"].map("${:,.2f}".format)

# Display the updated high-level snapshot of the local government area's key metrics
local_government_area_summary
# Out:
#    Total Unique Schools Total Students    Total Budget  Average Maths Score  \
# 0                    15         39,170  $24,649,428.00            70.338192
#
#    Average Reading Score  % Passing Math  % Passing Reading  % Overall Passing
# 0              69.980138       86.078632          84.426857          72.808272

# %% [markdown]
# ## School Summary

# %% [markdown]
# * Create an overview table that summarises key metrics about each school, including:
#   * School Name
#   * School Type
#   * Total Students
#   * Total School Budget
#   * Per Student Budget
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * % Overall Passing (The percentage of students that passed maths **and** reading.)
#
# * Create a dataframe to hold the above results

# %%
# Group the data by school_name
grouped_school_data = school_data_complete.groupby('school_name')

# Calculate the total students for each school
total_students_per_school = grouped_school_data['Student ID'].count()

# Calculate the school type (assuming it's the same for each school)
school_type = grouped_school_data['type'].first()

# Calculate the total school budget for each school (assuming it's the same for each school)
total_budget_per_school = grouped_school_data['budget'].first()

# Calculate the per student budget for each school
per_student_budget = total_budget_per_school / total_students_per_school

# Calculate the average math score for each school
average_math_score_per_school = grouped_school_data['maths_score'].mean()

# Calculate the average reading score for each school
average_reading_score_per_school = grouped_school_data['reading_score'].mean()

# Calculate the percentage passing math for each school
passing_math_per_school = (school_data_complete[school_data_complete['maths_score'] >= 50].groupby('school_name')['maths_score'].count() / total_students_per_school) * 100

# Calculate the percentage passing reading for each school
passing_reading_per_school = (school_data_complete[school_data_complete['reading_score'] >= 50].groupby('school_name')['reading_score'].count() / total_students_per_school) * 100

# Calculate the percentage overall passing (both math and reading) for each school
passing_overall_per_school = (school_data_complete[(school_data_complete['maths_score'] >= 50) & (school_data_complete['reading_score'] >= 50)].groupby('school_name')['Student ID'].count() / total_students_per_school) * 100

# Create the School Summary DataFrame
school_summary_df = pd.DataFrame({
    "School Type": school_type,
    "Total Students": total_students_per_school,
    "Total School Budget": total_budget_per_school,
    "Per Student Budget": per_student_budget,
    "Average Maths Score": average_math_score_per_school,
    "Average Reading Score": average_reading_score_per_school,
    "% Passing Maths": passing_math_per_school,
    "% Passing Reading": passing_reading_per_school,
    "% Overall Passing": passing_overall_per_school
})

# Format the columns with comma separators and a dollar symbol (similar to previous formatting)
school_summary_df["Total Students"] = school_summary_df["Total Students"].map("{:,}".format)
school_summary_df["Total School Budget"] = school_summary_df["Total School Budget"].map("${:,.2f}".format)
school_summary_df["Per Student Budget"] = school_summary_df["Per Student Budget"].map("${:,.2f}".format)

# Display the School Summary DataFrame with the index column header removed
school_summary_df.index.name = None
school_summary_df
# Out:
#                        School Type Total Students Total School Budget  \
# Bailey High School      Government          4,976       $3,124,928.00
# Cabrera High School    Independent          1,858       $1,081,356.00
# Figueroa High School    Government          2,949       $1,884,411.00
# Ford High School        Government          2,739       $1,763,916.00
# Griffin High School    Independent          1,468         $917,500.00
# Hernandez High School   Government          4,635       $3,022,020.00
# Holden High School     Independent            427         $248,087.00
# Huang High School       Government          2,917       $1,910,635.00
# Johnson High School     Government          4,761       $3,094,650.00
# Pena High School       Independent            962         $585,858.00
# Rodriguez High School   Government          3,999       $2,547,363.00
# Shelton High School    Independent          1,761       $1,056,600.00
# ...

# %% [markdown]
# ## Top Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the top five performing schools by % overall passing.

# %%
# Sort the schools by % Overall Passing in descending order
top_schools = school_summary_df.sort_values(by='% Overall Passing', ascending=False)

# Display the top 5 rows of the sorted DataFrame
top_schools.head()
# Out:
#                        School Type Total Students Total School Budget  \
# Griffin High School    Independent          1,468         $917,500.00
# Cabrera High School    Independent          1,858       $1,081,356.00
# Bailey High School      Government          4,976       $3,124,928.00
# Wright High School     Independent          1,800       $1,049,400.00
# Rodriguez High School   Government          3,999       $2,547,363.00
#
#                       Per Student Budget  Average Maths Score  \
# Griffin High School              $625.00            71.788147
# Cabrera High School              $582.00            71.657158
# Bailey High School               $628.00            72.352894
# Wright High School               $583.00            72.047222
# Rodriguez High School            $637.00            72.047762
#
#                        Average Reading Score  % Passing Maths  \
# Griffin High School                71.245232        91.212534
# ...

# %% [markdown]
# ## Bottom Performing Schools (By % Overall Passing)

# %% [markdown]
# * Sort and display the five worst-performing schools by % overall passing.

# %%
# Sort the schools by % Overall Passing in ascending order
bottom_schools = school_summary_df.sort_values(by='% Overall Passing')

# Display the top 5 rows of the sorted DataFrame
bottom_schools.head()
# Out:
#                        School Type Total Students Total School Budget  \
# Hernandez High School   Government          4,635       $3,022,020.00
# Huang High School       Government          2,917       $1,910,635.00
# Johnson High School     Government          4,761       $3,094,650.00
# Wilson High School     Independent          2,283       $1,319,574.00
# Ford High School        Government          2,739       $1,763,916.00
#
#                       Per Student Budget  Average Maths Score  \
# Hernandez High School            $652.00            68.874865
# Huang High School                $655.00            68.935207
# Johnson High School              $650.00            68.843100
# Wilson High School               $578.00            69.170828
# Ford High School                 $644.00            69.091274
#
#                        Average Reading Score  % Passing Maths  \
# Hernandez High School              69.186408        80.949299
# ...

# %% [markdown]
# ## Maths Scores by Year

# %% [markdown]
# * Create a table that lists the average maths score for students of each year level (9, 10, 11, 12) at each school.
#
#   * Create a pandas series for each year. Hint: use a conditional statement.
#
#   * Group each series by school
#
#   * Combine the series into a dataframe
#
#   * Optional: give the displayed data cleaner formatting

# %%
# Group the data by school_name and year
grouped_math_scores_by_year = school_data_complete.groupby(['school_name', 'year'])

# Calculate the average math score for each school and year level
average_math_scores_by_year = grouped_math_scores_by_year['maths_score'].mean()

# Create the Maths Scores by Year DataFrame
math_scores_by_year_df = pd.DataFrame(average_math_scores_by_year).reset_index()

# Pivot the DataFrame to have year levels as columns and schools as rows
math_scores_by_year_pivot = math_scores_by_year_df.pivot(index='school_name', columns='year', values='maths_score')

# Rename the columns with year levels
math_scores_by_year_pivot.columns = ['Math Score - Year 9', 'Math Score - Year 10', 'Math Score - Year 11', 'Math Score - Year 12']

# Display the Maths Scores by Year DataFrame
math_scores_by_year_pivot.index.name = None
math_scores_by_year_pivot
# Out:
#                        Math Score - Year 9  Math Score - Year 10  \
# Bailey High School               72.493827             71.897498
# Cabrera High School              72.321970             72.437768
# Figueroa High School             68.477804             68.331586
# Ford High School                 69.021609             69.387006
# Griffin High School              72.789731             71.093596
# Hernandez High School            68.586831             68.867156
# Holden High School               70.543307             75.105263
# Huang High School                69.081754             68.533246
# Johnson High School              69.469286             67.990220
# Pena High School                 71.996364             72.396000
# Rodriguez High School            71.940722             71.779808
# Shelton High School              72.932075             72.506696
# Thomas High School               69.234273             70.057007
# ...

# %% [markdown]
# ## Reading Score by Year

# %% [markdown]
# * Perform the same operations as above for reading scores

# %%
# Group the data by school_name and year
grouped_reading_scores_by_year = school_data_complete.groupby(['school_name', 'year'])

# Calculate the average reading score for each school and year level
average_reading_scores_by_year = grouped_reading_scores_by_year['reading_score'].mean()

# Create the Reading Scores by Year DataFrame
reading_scores_by_year_df = pd.DataFrame(average_reading_scores_by_year).reset_index()

# Pivot the DataFrame to have year levels as columns and schools as rows
reading_scores_by_year_pivot = reading_scores_by_year_df.pivot(index='school_name', columns='year', values='reading_score')

# Rename the columns with year levels
reading_scores_by_year_pivot.columns = ['Reading Score - Year 9', 'Reading Score - Year 10', 'Reading Score - Year 11', 'Reading Score - Year 12']

# Display the Reading Scores by Year DataFrame
reading_scores_by_year_pivot.index.name = None
reading_scores_by_year_pivot
# Out:
#                        Reading Score - Year 9  Reading Score - Year 10  \
# Bailey High School                  70.901920                70.848265
# Cabrera High School                 71.172348                71.328326
# Figueroa High School                70.261682                67.677588
# Ford High School                    69.615846                68.988701
# Griffin High School                 72.026895                70.746305
# Hernandez High School               68.477569                70.621842
# Holden High School                  71.598425                71.096491
# Huang High School                   68.670616                69.516297
# Johnson High School                 68.719286                69.295029
# Pena High School                    70.949091                72.324000
# Rodriguez High School               70.902921                70.137500
# Shelton High School                 70.715094                69.879464
# ...

# %% [markdown]
# ## Scores by School Spending

# %% [markdown]
# * Create a table that breaks down school performances based on average Spending Ranges (Per Student). Use 4 reasonable bins to group school spending. Include in the table each of the following:
#   * Average Maths Score
#   * Average Reading Score
#   * % Passing Maths
#   * % Passing Reading
#   * Overall Passing Rate (Average of the above two)

# %%
# Create four bins with reasonable cutoff values to group school spending
spending_bins = [0, 585, 630, 645, 680]
labels = ["<$585", "$585-630", "$630-645", "$645-680"]

# Categorize spending based on the bins
school_summary_df["Spending Ranges (Per Student)"] = pd.cut(school_summary_df["Per Student Budget"].str.replace("$", "").str.replace(",", "").astype(float), spending_bins, labels=labels, include_lowest=True)

# Calculate mean scores per spending range
spending_math_scores = school_summary_df.groupby(["Spending Ranges (Per Student)"])["Average Maths Score"].mean()
spending_reading_scores = school_summary_df.groupby(["Spending Ranges (Per Student)"])["Average Reading Score"].mean()
spending_passing_math = school_summary_df.groupby(["Spending Ranges (Per Student)"])["% Passing Maths"].mean()
spending_passing_reading = school_summary_df.groupby(["Spending Ranges (Per Student)"])["% Passing Reading"].mean()
overall_passing_spending = school_summary_df.groupby(["Spending Ranges (Per Student)"])["% Overall Passing"].mean()

# Create the Scores by School Spending DataFrame (spending_summary)
spending_summary = pd.DataFrame({
    "Average Maths Score": spending_math_scores,
    "Average Reading Score": spending_reading_scores,
    "% Passing Maths": spending_passing_math,
    "% Passing Reading": spending_passing_reading,
    "% Overall Passing": overall_passing_spending
})

# Format the DataFrame with percentage formatting (if needed)
spending_summary["Average Maths Score"] = spending_summary["Average Maths Score"].map("{:.2f}".format)
spending_summary["Average Reading Score"] = spending_summary["Average Reading Score"].map("{:.2f}".format)
spending_summary["% Passing Maths"] = spending_summary["% Passing Maths"].map("{:.2f}%".format)
spending_summary["% Passing Reading"] = spending_summary["% Passing Reading"].map("{:.2f}%".format)
spending_summary["% Overall Passing"] = spending_summary["% Overall Passing"].map("{:.2f}%".format)

# Display the Scores by School Spending DataFrame (spending_summary)
spending_summary
# Out:
#                               Average Maths Score Average Reading Score  \
# Spending Ranges (Per Student)
# <$585                                       71.36                 70.72
# $585-630                                    72.07                 71.03
# $630-645                                    69.85                 69.84
# $645-680                                    68.88                 69.05
#
#                               % Passing Maths % Passing Reading  \
# Spending Ranges (Per Student)
# <$585                                  88.84%            86.39%
# $585-630                               91.52%            87.29%
# $630-645                               84.69%            83.76%
# $645-680                               81.57%            81.77%
#
#                               % Overall Passing
# Spending Ranges (Per Student)
# <$585                                    76.72%
# $585-630                                 79.88%
# ...

# %% [markdown]
# ## Scores by School Size

# %% [markdown]
# * Perform the same operations as above, based on school size.

# %%
# Remove comma separators from the "Total Students" column
school_summary_df["Total Students"] = school_summary_df["Total Students"].str.replace(",", "")

# Convert the "Total Students" column to integers
school_summary_df["Total Students"] = school_summary_df["Total Students"].astype(int)

# Create bins for school size
size_bins = [0, 1000, 2000, 5000]
labels = ["Small (<1000)", "Medium (1000-2000)", "Large (2000-5000)"]

# Categorize school size based on the bins
school_summary_df["School Size"] = pd.cut(school_summary_df["Total Students"], size_bins, labels=labels, include_lowest=True)

# Calculate mean scores per school size
size_math_scores = school_summary_df.groupby(["School Size"])["Average Maths Score"].mean()
size_reading_scores = school_summary_df.groupby(["School Size"])["Average Reading Score"].mean()
size_passing_math = school_summary_df.groupby(["School Size"])["% Passing Maths"].mean()
size_passing_reading = school_summary_df.groupby(["School Size"])["% Passing Reading"].mean()
overall_passing_size = school_summary_df.groupby(["School Size"])["% Overall Passing"].mean()

# Create the Scores by School Size DataFrame (size_summary)
size_summary = pd.DataFrame({
    "Average Maths Score": size_math_scores,
    "Average Reading Score": size_reading_scores,
    "% Passing Maths": size_passing_math,
    "% Passing Reading": size_passing_reading,
    "% Overall Passing": overall_passing_size
})

# Format the DataFrame with percentage formatting (if needed)
size_summary["Average Maths Score"] = size_summary["Average Maths Score"].map("{:.2f}".format)
size_summary["Average Reading Score"] = size_summary["Average Reading Score"].map("{:.2f}".format)
size_summary["% Passing Maths"] = size_summary["% Passing Maths"].map("{:.2f}%".format)
size_summary["% Passing Reading"] = size_summary["% Passing Reading"].map("{:.2f}%".format)
size_summary["% Overall Passing"] = size_summary["% Overall Passing"].map("{:.2f}%".format)

# Display the Scores by School Size DataFrame (size_summary)
size_summary
# Out:
#                    Average Maths Score Average Reading Score % Passing Maths  \
# School Size
# Small (<1000)                    72.34                 71.64          90.81%
# Medium (1000-2000)               71.42                 70.72          89.85%
# Large (2000-5000)                69.75                 69.58          84.25%
#
#                    % Passing Reading % Overall Passing
# School Size
# Small (<1000)                 87.56%            79.07%
# Medium (1000-2000)            86.71%            78.04%
# Large (2000-5000)             83.30%            70.29%

# %% [markdown]
# ## Scores by School Type

# %% [markdown]
# * Perform the same operations as above, based on school type

# %%
# Calculate mean scores per school type
type_math_scores = school_summary_df.groupby(["School Type"])["Average Maths Score"].mean()
type_reading_scores = school_summary_df.groupby(["School Type"])["Average Reading Score"].mean()
type_passing_math = school_summary_df.groupby(["School Type"])["% Passing Maths"].mean()
type_passing_reading = school_summary_df.groupby(["School Type"])["% Passing Reading"].mean()
overall_passing_type = school_summary_df.groupby(["School Type"])["% Overall Passing"].mean()

# Create the Scores by School Type DataFrame (type_summary)
type_summary = pd.DataFrame({
    "Average Maths Score": type_math_scores,
    "Average Reading Score": type_reading_scores,
    "% Passing Maths": type_passing_math,
    "% Passing Reading": type_passing_reading,
    "% Overall Passing": overall_passing_type
})

# Format the DataFrame with percentage formatting (if needed)
type_summary["Average Maths Score"] = type_summary["Average Maths Score"].map("{:.2f}".format)
type_summary["Average Reading Score"] = type_summary["Average Reading Score"].map("{:.2f}".format)
type_summary["% Passing Maths"] = type_summary["% Passing Maths"].map("{:.2f}%".format)
type_summary["% Passing Reading"] = type_summary["% Passing Reading"].map("{:.2f}%".format)
type_summary["% Overall Passing"] = type_summary["% Overall Passing"].map("{:.2f}%".format)

# Display the Scores by School Type DataFrame (type_summary)
type_summary
# Out:
#             Average Maths Score Average Reading Score % Passing Maths  \
# School Type
# Government                69.83                 69.68          84.46%
# Independent               71.37                 70.72          89.20%
#
#             % Passing Reading % Overall Passing
# School Type
# Government             83.59%            70.70%
# Independent            86.25%            76.97%
